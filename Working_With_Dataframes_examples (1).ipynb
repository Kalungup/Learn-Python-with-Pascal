# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/Python-Notebook-Banners/Examples.png"  style="display: block; margin-left: auto; margin-right: auto;";/>
# </div>

# %% [markdown]
# # Examples: Working with DataFrames

# %% [markdown]
# In this notebook, we cover how to manipulate, transform, and alter Pandas DataFrames.

# %% [markdown]
# ## Learning objectives
#
# * Know how to sort, filter, and group Pandas DataFrames.
# * Understand how to create and delete columns in Pandas DataFrames.
# * Know how to apply custom transformations to Pandas DataFrames.

# %% [markdown]
# ## Introduction
#
# When a dataset only has a few data points, it's very easy to manually apply operations to the entire dataset. However, good datasets are very rarely this small.
#
# The Pandas library in Python allows us to use **vectorised operations** (i.e. operations across multiple data points simultaneously), making it much easier to **work with large amounts of data**.
#
# In this train, we look at how to **manipulate data within DataFrames**.
#
# Let's start by **importing** the **Pandas library** and the **dataset**.

# %%
import pandas as pd

# %% [markdown]
# **Note:** A new version of the Pandas package, `Pandas 2`, was released in April 2023. While it comes with added functionality, we continue to use `Pandas 1` in this train for stability purposes.

# %%
df = pd.read_csv("students.csv",index_col = "Name")
df.head()
# Out:
#         StudentID  Age   Country            Course  Score
# Name
# Pascal          1   49    Sweden         Education     85
# Godwin          2   49     Kenya        Management     90
# Amina           3   23    Uganda  Computer Science     78
# John            4   21  Tanzania       Engineering     88
# Sara            5   25    Norway      Data Science     92

# %%
df.shape
# Out:
# (8, 5)

# %%
# Load data - pass 'Name' as our index column.
df = pd.read_csv('football_players.csv', index_col='Name')

# Use the head() function to look at the first 5 rows.
df.head()
# Out:
# C:\Users\Ideapad\AppData\Local\Temp\ipykernel_12704\205277898.py:2: DtypeWarning: Columns (14,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('football_players.csv', index_col='Name')
#                    Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# Cristiano Ronaldo   32    Portugal       94       89         63      89
# L. Messi            30   Argentina       93       92         48      90
# Neymar              25      Brazil       92       94         56      96
# L. Suárez           30     Uruguay       92       88         78      86
# M. Neuer            31     Germany       92       58         29      52
#
#                   Balance Ball control Composure Crossing  ... Short passing  \
# Name                                                       ...
# Cristiano Ronaldo  63           93        95       85      ...        83
# L. Messi           95           95        96       77      ...        88
# Neymar             82           95        92       75      ...        81
# L. Suárez          60           91        83       77      ...        83
# M. Neuer           35           48        70       15      ...        55
#
#                   Shot power Sliding tackle Sprint speed Stamina  \
# Name
# Cristiano Ronaldo     94             23           91      92
# L. Messi              85             26           87      73
# Neymar                80             33           90      78
# L. Suárez             87             38           77      89
# M. Neuer              25             11           61      44
#
#                   Standing tackle Strength  Vision Volleys Preferred Positions
# Name
# Cristiano Ronaldo          31       80      85      88                  ST LW
# L. Messi                   28       59      90      85                     RW
# Neymar                     24       53      80      83                     LW
# L. Suárez                  45       80      84      88                     ST
# M. Neuer                   10       83      70      11                     GK
#
# [5 rows x 38 columns]

# %%
df.describe()
# Out:
#                 Age       Overall
# count  18054.000000  18054.000000
# mean      25.155312     66.326410
# std        4.613449      7.081938
# min       16.000000     46.000000
# 25%       21.000000     62.000000
# 50%       25.000000     66.000000
# 75%       28.000000     71.000000
# max       47.000000     94.000000

# %% [markdown]
# ## Sorting
#
# One basic operation to perform when working with a large dataset is to **sort the values using some criteria**.
#
# For DataFrames, sorting can be achieved by using the `sort_values()` function. To **sort** data entries **by a specific column(s)**, we need to pass the column(s) to the function.
#
# Let's look at some examples:

# %% [markdown]
# ### Example 1a

# %%
# Sort by age from youngest to oldest (select first 10 entries).
df.sort_values(by='Age').head(10)
# Out:
#                Age  Nationality  Overall Acceleration Aggression Agility  \
# Name
# G. McEachran    16      England       59       64         48      72
# Javi Vázquez    16        Spain       58       61         53      48
# M. Sprang       16      Germany       57       18         12      19
# V. Barbero      16    Argentina       54       73         34      76
# L. Pintor       16       France       54       72         29      70
# A. Gomes        16      England       64    27546         36      82
# R. Strechie     16      Romania       54       64         51      63
# L. Geertruida   16  Netherlands       59       72         47      54
# J. Hove         16       Norway       51       57         57      58
# E. Vignato      16        Italy       61       69         13      69
#
#               Balance Ball control Composure Crossing  ... Short passing  \
# Name                                                   ...
# G. McEachran   74           61        63       54      ...        66
# Javi Vázquez   65           47        43       33      ...        41
# M. Sprang      29           10        18       12      ...        19
# V. Barbero     77           48        52       52      ...        50
# L. Pintor      68           56        43       27      ...        30
# A. Gomes       90           66        57       61      ...          63+3
# R. Strechie    61           52        47       43      ...        60
# L. Geertruida  66           58        31       49      ...        60
# J. Hove        56           51        42       40      ...        56
# E. Vignato     69           69        52       60      ...        68
#
#               Shot power Sliding tackle Sprint speed Stamina Standing tackle  \
# Name
# G. McEachran      47             54           62      54              55
# Javi Vázquez      42             59           64      59              63
# M. Sprang         17             13           16      32              14
# V. Barbero        51             25           75      60              25
# L. Pintor         57             12           68      36              10
# A. Gomes          61             20        25842      58              19
# R. Strechie       52             50           61      61              54
# L. Geertruida     29             57           63      45              62
# J. Hove           50             56           64      47              51
# E. Vignato        52             30           65      59              22
#
#               Strength  Vision Volleys Preferred Positions
# Name
# G. McEachran    36      64      46                 CM CAM
# Javi Vázquez    55      37      29                     CB
# M. Sprang       38      59      12                     GK
# V. Barbero      42      48      50                     RM
# L. Pintor       34      38      48                     ST
# A. Gomes        34        63+7    57+1       CM RW LW CAM
# R. Strechie     62      53      28                     CM
# L. Geertruida   61      26      27                  RB CB
# J. Hove         54      56      29                     CM
# E. Vignato      33      52      57                    CAM
#
# [10 rows x 38 columns]

# %% [markdown]
# ### Example 1b

# %%
# Sort by age from youngest to oldest (select first 5 entries), then by Overall, also ascending.
df.sort_values(by=['Age', 'Overall']).head()
# Out:
#              Age Nationality  Overall Acceleration Aggression Agility Balance  \
# Name
# J. Hove       16      Norway       51       57         57      58      56
# R. Strechie   16     Romania       54       64         51      63      61
# L. Pintor     16      France       54       72         29      70      68
# V. Barbero    16   Argentina       54       73         34      76      77
# M. Sprang     16     Germany       57       18         12      19      29
#
#             Ball control Composure Crossing  ... Short passing Shot power  \
# Name                                         ...
# J. Hove           51        42       40      ...        56         50
# R. Strechie       52        47       43      ...        60         52
# L. Pintor         56        43       27      ...        30         57
# V. Barbero        48        52       52      ...        50         51
# M. Sprang         10        18       12      ...        19         17
#
#             Sliding tackle Sprint speed Stamina Standing tackle Strength  \
# Name
# J. Hove             56           64      47              51       54
# R. Strechie         50           61      61              54       62
# L. Pintor           12           68      36              10       34
# V. Barbero          25           75      60              25       42
# M. Sprang           13           16      32              14       38
#
#              Vision Volleys Preferred Positions
# Name
# J. Hove      56      29                     CM
# R. Strechie  53      28                     CM
# L. Pintor    38      48                     ST
# V. Barbero   48      50                     RM
# M. Sprang    59      12                     GK
#
# [5 rows x 38 columns]

# %% [markdown]
# ### Example 2
#
# When sorting values, the default option sorts data in ascending order. If we want to sort in descending order, we need to pass in the parameter `ascending=False`.

# %%
# Sort by age from oldest to youngest (select first 5 entries).
df.sort_values(by= ['Age', 'Overall'], ascending=False).head()
# Out:
#                Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# B. Richardson   47     England       46       25         44      35
# O. Pérez        44      Mexico       71       60         26      69
# E. El Hadary    44       Egypt       70       28         29      21
# D. Coyne        43       Wales       55       36         36      48
# J. Walker       43     England       55       22         41      53
#
#               Balance Ball control Composure Crossing  ... Short passing  \
# Name                                                   ...
# B. Richardson  44           22        44       11      ...        12
# O. Pérez       69           23        50       19      ...        26
# E. El Hadary   41           25        57       20      ...        16
# D. Coyne       58           31        57       13      ...        28
# J. Walker      64           38        35       16      ...        22
#
#               Shot power Sliding tackle Sprint speed Stamina Standing tackle  \
# Name
# B. Richardson     13             13           25      32              12
# O. Pérez          24             11           57      41              12
# E. El Hadary      18             15           39      34              19
# D. Coyne          21             19           33      37              16
# J. Walker         22             13           35      19              11
#
#               Strength  Vision Volleys Preferred Positions
# Name
# B. Richardson   47      17      12                     GK
# O. Pérez        66      40      13                     GK
# E. El Hadary    73      16      12                     GK
# D. Coyne        76      33      11                     GK
# J. Walker       62      32      11                     GK
#
# [5 rows x 38 columns]

# %% [markdown]
# ## Filtering
#
# Another useful thing to do with a DataFrame is to filter the values to **only view the data we are interested in**.
#
# If we **pass in any condition inside the square brackets** after the DataFrame name, we filter out rows that fail to meet that condition. For example, the command `df['Age' > 30]` returns a boolean series containing the players' names (the index for our DataFrame) and whether the age is above 30 or not. When this is used to filter on our original DataFrame, it returns only rows that meet the condition.

# %% [markdown]
# ### Example 3

# %%
# Filter on players older than 30.
df[df['Age'] > 30]
# Out:
#                    Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# Cristiano Ronaldo   32    Portugal       94       89         63      89
# M. Neuer            31     Germany       92       58         29      52
# Sergio Ramos        31       Spain       90       75         84      79
# L. Modrić           31     Croatia       89       75         62      93
# G. Chiellini        32       Italy       89       68         92      59
# ...                ...         ...      ...          ...        ...     ...
# D. Subašić          32     Croatia       85       51         31      42
# C. Marchisio        31       Italy       85       78         78      81
# Filipe Luís         31      Brazil       85       75         81      74
# V. Kompany          31     Belgium       85       61         87      60
# A. Barzagli         36       Italy       85       64         70      51
#
#                   Balance Ball control Composure Crossing  ... Short passing  \
# Name                                                       ...
# Cristiano Ronaldo  63           93        95       85      ...        83
# M. Neuer           35           48        70       15      ...        55
# Sergio Ramos       60           84        80       66      ...        78
# L. Modrić          94           92        84       78      ...        92
# G. Chiellini       64           57        82       58      ...        59
# ...                   ...          ...       ...      ...  ...           ...
# D. Subašić         37           19        65       11      ...        24
# C. Marchisio       79           85        84       76      ...        87
# Filipe Luís        60           81        88       84      ...        78
# V. Kompany         42           68        81       61      ...        72
# A. Barzagli        64           65        82       40      ...        65
#
#                   Shot power Sliding tackle Sprint speed Stamina  \
# Name
# Cristiano Ronaldo     94             23           91      92
# M. Neuer              25             11           61      44
# Sergio Ramos          79             91           77      84
# L. Modrić             73             73           71      82
# G. Chiellini          78             90           78      68
# ...                      ...            ...          ...     ...
# D. Subašić            24             13           54      32
# C. Marchisio          82             80           78      81
# Filipe Luís           71             86           82      91
# V. Kompany            75             84           64      74
# A. Barzagli           54             88           76      46
#
#                   Standing tackle Strength  Vision Volleys Preferred Positions
# Name
# Cristiano Ronaldo          31       80      85      88                  ST LW
# M. Neuer                   10       83      70      11                     GK
# Sergio Ramos               89       81      63      66                     CB
# L. Modrić                  80       58      90      74                 CDM CM
# G. Chiellini               92       91      50      45                     CB
# ...                           ...      ...     ...     ...                 ...
# D. Subašić                 14       80      52      13                     GK
# C. Marchisio               78       70      84      76                 CDM CM
# Filipe Luís                83       74      70      56                     LB
# V. Kompany                 85       88      59      46                     CB
# A. Barzagli                90       87      62      35                     CB
#
# [2549 rows x 38 columns]

# %%
df[(df['Age'] > 40) & (df['Overall'] > 70)]
# Out:
#           Age Nationality  Overall Acceleration Aggression Agility Balance  \
# Name
# O. Pérez   44      Mexico       71       60         26      69      69
#
#          Ball control Composure Crossing  ... Short passing Shot power  \
# Name                                      ...
# O. Pérez       23        50       19      ...        26         24
#
#          Sliding tackle Sprint speed Stamina Standing tackle Strength  Vision  \
# Name
# O. Pérez         11           57      41              12       66      40
#
#          Volleys Preferred Positions
# Name
# O. Pérez  13                     GK
#
# [1 rows x 38 columns]

# %% [markdown]
# ### Example 4
#
# We can also **pass multiple conditions** in the square brackets by using the `|` and `&` operators.
#
# **Note:** Each condition should be closed inside round brackets as well.

# %%
# Filter on players older than 30 and overall rating greater than 90.
df[(df['Age'] > 30) & (df['Overall'] > 90)]
# Out:
#                    Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# Cristiano Ronaldo   32    Portugal       94       89         63      89
# M. Neuer            31     Germany       92       58         29      52
#
#                   Balance Ball control Composure Crossing  ... Short passing  \
# Name                                                       ...
# Cristiano Ronaldo  63           93        95       85      ...        83
# M. Neuer           35           48        70       15      ...        55
#
#                   Shot power Sliding tackle Sprint speed Stamina  \
# Name
# Cristiano Ronaldo     94             23           91      92
# M. Neuer              25             11           61      44
#
#                   Standing tackle Strength  Vision Volleys Preferred Positions
# Name
# Cristiano Ronaldo          31       80      85      88                  ST LW
# M. Neuer                   10       83      70      11                     GK
#
# [2 rows x 38 columns]

# %% [markdown]
# ## Creating columns
#
# We can **create new columns from existing** columns in a Pandas DataFrame.
#
# We simply **define the new column name** as a string inside square brackets, followed by an `=` sign, and then the **function or operation** applied to the existing column(s).

# %% [markdown]
# ### Example 5

# %%
# Create a column of rating per year of age.
df['Rating Per Year of Age'] = df['Overall'] / df['Age']

# Look at the first 5 entries.
df['Rating Per Year of Age'].head()
# Out:
# Name
# Cristiano Ronaldo    2.937500
# L. Messi             3.100000
# Neymar               3.680000
# L. Suárez            3.066667
# M. Neuer             2.967742
# Name: Rating Per Year of Age, dtype: float64

# %%
df.shape
# Out:
# (18054, 39)

# %% [markdown]
# ## Deleting columns
#
# Columns can be deleted using the `drop()` function.
#
# The arguments are the **column name** and the **axis** which should be:
# - **1** if we are deleting **columns.**
# - **0** if we are deleting **rows**.

# %%
df.shape
# Out:
# (18054, 39)

# %% [markdown]
# ### Example 6

# %%
# Drop the column we just created in Example 5
df = df.drop('Rating Per Year of Age', axis=1)

df.head()
# Out:
#                    Age Nationality  Overall  Acceleration  Aggression  \
# Name
# Cristiano Ronaldo   32    Portugal     94.0          89.0        63.0
# L. Messi            30   Argentina     93.0          92.0        48.0
# Neymar              25      Brazil     92.0          94.0        56.0
# L. Suárez           30     Uruguay     92.0          88.0        78.0
# M. Neuer            31     Germany     92.0          58.0        29.0
#
#                    Agility  Balance  Ball control  Composure  Crossing  ...  \
# Name                                                                    ...
# Cristiano Ronaldo     89.0     63.0          93.0       95.0      85.0  ...
# L. Messi              90.0     95.0          95.0       96.0      77.0  ...
# Neymar                96.0     82.0          95.0       92.0      75.0  ...
# L. Suárez             86.0     60.0          91.0       83.0      77.0  ...
# M. Neuer              52.0     35.0          48.0       70.0      15.0  ...
#
#                    Shot power  Sliding tackle  Sprint speed  Stamina  \
# Name
# Cristiano Ronaldo        94.0            23.0          91.0     92.0
# L. Messi                 85.0            26.0          87.0     73.0
# Neymar                   80.0            33.0          90.0     78.0
# L. Suárez                87.0            38.0          77.0     89.0
# M. Neuer                 25.0            11.0          61.0     44.0
#
#                    Standing tackle  Strength  Vision  Volleys  \
# Name
# Cristiano Ronaldo             31.0      80.0    85.0     88.0
# L. Messi                      28.0      59.0    90.0     85.0
# Neymar                        24.0      53.0    80.0     83.0
# L. Suárez                     45.0      80.0    84.0     88.0
# M. Neuer                      10.0      83.0    70.0     11.0
#
#                    Preferred Positions  Preferred Positions Type
# Name
# Cristiano Ronaldo               ST LW                    Forward
# L. Messi                           RW                    Forward
# Neymar                             LW                    Forward
# L. Suárez                          ST                    Forward
# M. Neuer                           GK                 GoalKeeper
#
# [5 rows x 39 columns]

# %% [markdown]
# ## Grouping data
#
# We can also **group** the data in a DataFrame **according to desired criteria**.
#
# Grouping in DataFrames can be achieved using the `groupby()` function.
#
# Depending on our application, we **may need to call an aggregation function** for the grouped data after the `groupby()` function call. Examples of aggregation functions include `mean()`, `sum()`, `min()`, and `max()`. This will result in **a column of values from the chosen aggregation** (for numeric columns).

# %% [markdown]
# ### Example 7

# %%
# Let's look at the average rating by age (first 5 rows).
df.groupby('Age')[['Overall']].mean().head()
# Out:
#        Overall
# Age
# 16   57.846154
# 17   56.089147
# 18   57.287202
# 19   59.430309
# 20   61.559839

# %% [markdown]
# ### Example 8
#
# It is possible to **group by more than one column**. We simply need to pass the list of columns.

# %%
# Look at the average rating by age and nationality (first 15 rows).
df.groupby(['Age', 'Nationality'])[['Overall']].mean().head(15)
# Out:
#                    Overall
# Age Nationality
# 16  Argentina    56.000000
#     England      61.500000
#     France       54.000000
#     Germany      57.000000
#     Italy        61.000000
#     Netherlands  62.000000
#     Norway       54.500000
#     Romania      54.000000
#     Spain        58.000000
# 17  Algeria      54.000000
#     Argentina    57.333333
#     Australia    52.000000
#     Austria      54.500000
#     Belgium      58.250000
#     Canada       56.000000

# %% [markdown]
# ## Transforming data
#
# It is often the case that we want to **format columns inside our DataFrame**.
#
# We can transform a column using the `apply()` function, while we use the `map()` function to transform multiple columns at once. We can create a function by using `def` or `lambda`.

# %% [markdown]
# ### Example 9
#
# **a) Apply a custom function to a DataFrame**
#
# To format a column in our dataset, we start by creating the function.

# %%
# Using def to create a custom function.
def year_to_month(x):
    "Converts no of years to no of months"
    return x * 12

# %% [markdown]
# We then apply the function to the intended column.

# %%
# Change the age column to months and look at the first 5 entries.
df['Age'].apply(year_to_month).head()
# Out:
# Name
# Cristiano Ronaldo    384
# L. Messi             360
# Neymar               300
# L. Suárez            360
# M. Neuer             372
# Name: Age, dtype: int64

# %% [markdown]
# ### Example 10
#
# **b) Using a lambda function on a DataFrame**
#
# We can also use a lambda function and apply it to the DataFrame. A lambda operator or lambda function is used for **creating small, one-time, anonymous function objects** in Python.
#
# **Basic syntax:**
#
# ```python
# lambda [arguments]: [expression]
# ```
#
# Lambda operators can have any number of arguments, but they can have **only one expression**. It cannot contain any  `print` or `raise` statements, and it returns a function object which can be assigned to any variable.

# %%
# Using a lambda operator.
year_to_month_lamb = lambda x: x * 12

# %%
# Print function answer.
print('def: ', year_to_month(30))
print('lambda: ', year_to_month_lamb(30))
# Out:
# def:  360
# lambda:  360

# %% [markdown]
# In the example above, we can see that both function versions, `def` and `lambda`, produce the same output. The difference is that the `lambda` can only have a single expression and does not need to return anything.
#
# Let's use the lambda function to format a column in our dataset:

# %%
# Change the age column to months and look at the first 5 entries.
df['Age'].apply(lambda x: x*12).head()
# Out:
# Name
# Cristiano Ronaldo    384
# L. Messi             360
# Neymar               300
# L. Suárez            360
# M. Neuer             372
# Name: Age, dtype: int64

# %% [markdown]
# ### Example 11
#
# Let's try to create a function that creates a column with the **player position type**, where types can be `Forward`, `Midfielder`, `Back`, or `GoalKeeper`.

# %%
df
# Out:
#                    Age Nationality  Overall  Acceleration  Aggression  \
# Name
# Cristiano Ronaldo   32    Portugal     94.0          89.0        63.0
# L. Messi            30   Argentina     93.0          92.0        48.0
# Neymar              25      Brazil     92.0          94.0        56.0
# L. Suárez           30     Uruguay     92.0          88.0        78.0
# M. Neuer            31     Germany     92.0          58.0        29.0
# ...                ...         ...      ...           ...         ...
# Carvajal            25       Spain     84.0          76.0        81.0
# J. Draxler          23     Germany     84.0          76.0        48.0
# M. Icardi           24   Argentina     84.0          75.0        55.0
# Morata              24       Spain     84.0          78.0        54.0
# K. Koulibaly        26     Senegal     84.0          69.0        87.0
#
#                    Agility  Balance  Ball control  Composure  Crossing  ...  \
# Name                                                                    ...
# Cristiano Ronaldo     89.0     63.0          93.0       95.0      85.0  ...
# L. Messi              90.0     95.0          95.0       96.0      77.0  ...
# Neymar                96.0     82.0          95.0       92.0      75.0  ...
# L. Suárez             86.0     60.0          91.0       83.0      77.0  ...
# M. Neuer              52.0     35.0          48.0       70.0      15.0  ...
# ...                    ...      ...           ...        ...       ...  ...
# Carvajal              82.0     79.0          83.0       74.0      83.0  ...
# J. Draxler            81.0     75.0          87.0       81.0      83.0  ...
# M. Icardi             74.0     76.0          77.0       82.0      46.0  ...
# Morata                62.0     56.0          84.0       79.0      73.0  ...
# K. Koulibaly          50.0     40.0          59.0       78.0      30.0  ...
#
#                    Shot power  Sliding tackle  Sprint speed  Stamina  \
# Name
# Cristiano Ronaldo        94.0            23.0          91.0     92.0
# L. Messi                 85.0            26.0          87.0     73.0
# Neymar                   80.0            33.0          90.0     78.0
# L. Suárez                87.0            38.0          77.0     89.0
# M. Neuer                 25.0            11.0          61.0     44.0
# ...                       ...             ...           ...      ...
# Carvajal                 64.0            86.0          86.0     84.0
# J. Draxler               86.0            26.0          79.0     68.0
# M. Icardi                81.0            21.0          80.0     70.0
# Morata                   80.0            20.0          86.0     70.0
# K. Koulibaly             55.0            85.0          76.0     73.0
#
#                    Standing tackle  Strength  Vision  Volleys  \
# Name
# Cristiano Ronaldo             31.0      80.0    85.0     88.0
# L. Messi                      28.0      59.0    90.0     85.0
# Neymar                        24.0      53.0    80.0     83.0
# L. Suárez                     45.0      80.0    84.0     88.0
# M. Neuer                      10.0      83.0    70.0     11.0
# ...                            ...       ...     ...      ...
# Carvajal                      85.0      75.0    57.0     34.0
# J. Draxler                    35.0      67.0    84.0     84.0
# M. Icardi                     21.0      74.0    64.0     81.0
# Morata                        14.0      82.0    76.0     81.0
# K. Koulibaly                  87.0      93.0    34.0     14.0
#
#                    Preferred Positions  Preferred Positions Type
# Name
# Cristiano Ronaldo               ST LW                    Forward
# L. Messi                           RW                    Forward
# Neymar                             LW                    Forward
# L. Suárez                          ST                    Forward
# M. Neuer                           GK                 GoalKeeper
# ...                                ...                       ...
# Carvajal                           RB                       Back
# J. Draxler                  LM CAM LW                    Forward
# M. Icardi                          ST                    Forward
# Morata                             ST                    Forward
# K. Koulibaly                       CB                       Back
#
# [18054 rows x 39 columns]

# %%
# Create function.
def position_type(s):
    
    """"This function converts the individual positions (abbreviations) and classifies it
    as either a Forward, Midfielder, Back, or Goalkeeper"""
    
    if (s[-2] == 'T') | (s[-2] == 'W'):
        return 'Forward'
    elif s[-2] == 'M':
        return 'Midfielder'
    elif s[-2] == 'B':
        return 'Back'
    else:
        return 'GoalKeeper'

# %%
# Create position type column.
df['Preferred Positions Type'] = df['Preferred Positions'].apply(position_type)

# Look at the first 5 entries.
df['Preferred Positions Type'].head()
# Out:
# Name
# Cristiano Ronaldo       Forward
# L. Messi                Forward
# Neymar                  Forward
# L. Suárez               Forward
# M. Neuer             GoalKeeper
# Name: Preferred Positions Type, dtype: object

# %% [markdown]
# ### Example 12
#
# Let's create another function to transform many columns at once using the `map()` function.
#
# Before we go on, a lot of the columns look like they should be numerical but are actually stored as a string. We can check this by using the `info()` function:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18054 entries, Cristiano Ronaldo to K. Koulibaly
# Data columns (total 39 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       18054 non-null  int64
#  1   Nationality               18054 non-null  object
#  2   Overall                   18054 non-null  int64
#  3   Acceleration              18054 non-null  object
#  4   Aggression                18054 non-null  object
#  5   Agility                   18054 non-null  object
#  6   Balance                   18054 non-null  object
#  7   Ball control              18054 non-null  object
#  8   Composure                 18054 non-null  object
#  9   Crossing                  18054 non-null  object
#  10  Curve                     18054 non-null  object
#  11  Dribbling                 18054 non-null  object
#  12  Finishing                 18054 non-null  object
#  13  Free kick accuracy        18054 non-null  object
#  14  GK diving                 18054 non-null  object
#  15  GK handling               18054 non-null  object
#  16  GK kicking                18054 non-null  object
#  17  GK positioning            18054 non-null  object
#  18  GK reflexes               18054 non-null  object
#  19  Heading accuracy          18054 non-null  object
#  20  Interceptions             18054 non-null  object
#  21  Jumping                   18054 non-null  object
#  22  Long passing              18054 non-null  object
#  23  Long shots                18054 non-null  object
#  24  Marking                   18054 non-null  object
#  25  Penalties                 18054 non-null  object
#  26  Positioning               18054 non-null  object
#  27  Reactions                 18054 non-null  object
#  28  Short passing             18054 non-null  object
#  29  Shot power                18054 non-null  object
#  30  Sliding tackle            18054 non-null  object
#  31  Sprint speed              18054 non-null  object
#  32  Stamina                   18054 non-null  object
#  33  Standing tackle           18054 non-null  object
#  34  Strength                  18054 non-null  object
#  35  Vision                    18054 non-null  object
#  36  Volleys                   18054 non-null  object
#  37  Preferred Positions       18054 non-null  object
#  38  Preferred Positions Type  18054 non-null  object
# dtypes: int64(2), object(37)
# memory usage: 6.0+ MB

# %% [markdown]
# As we can see, most of the number columns (attributes) are stored as strings (objects).
#
# We will create a function that:
# - Transforms all the supposedly **numeric columns to a float**.
# - For the string-number columns, we will only select and **transform the first two digits** before the comma.

# %%
# Select all numeric attribute columns, i.e. excluding "word-type" columns such as Nationality.
cols = ['Overall', 'Acceleration', 'Aggression',
       'Agility', 'Balance', 'Ball control', 'Composure', 'Crossing', 'Curve',
       'Dribbling', 'Finishing', 'Free kick accuracy', 'GK diving',
       'GK handling', 'GK kicking', 'GK positioning', 'GK reflexes',
       'Heading accuracy', 'Interceptions', 'Jumping', 'Long passing',
       'Long shots', 'Marking', 'Penalties', 'Positioning', 'Reactions',
       'Short passing', 'Shot power', 'Sliding tackle', 'Sprint speed',
       'Stamina', 'Standing tackle', 'Strength', 'Vision', 'Volleys']

# %%
# Create function.
def to_float(x):    
    "Transforms numeric attribute columns to type float"
    
    if type(x) is int:
        return float(x)
    else:
        return float(x[0:2])

# %%
print(to_float('34.9'))
# Out:
# 34.0

# %%
# Use the map() function to transform all selected columns.
df[cols] = df[cols].map(to_float)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 2
#       1 # Use the map() function to transform all selected columns.
# ----> 2 df[cols] = df[cols].map(to_float)
#
# File c:\Users\Ideapad\.conda\envs\Pythonenvironment\Lib\site-packages\pandas\core\frame.py:10495, in DataFrame.map(self, func, na_action, **kwargs)
#   10492 def infer(x):
#   10493     return x._map_values(func, na_action=na_action)
# > 10495 return self.apply(infer).__finalize__(self, "map")
#
# File c:\Users\Ideapad\.conda\envs\Pythonenvironment\Lib\site-packages\pandas\core\frame.py:10401, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10387 from pandas.core.apply import frame_apply
#   10389 op = frame_apply(
#   10390     self,
#   10391     func=func,
#    (...)  10399     kwargs=kwargs,
#   10400 )
# > 10401 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\Ideapad\.conda\envs\Pythonenvironment\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File c:\Users\Ideapad\.conda\envs\Pythonenvironment\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File c:\Users\Ideapad\.conda\envs\Pythonenvironment\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# File c:\Users\Ideapad\.conda\envs\Pythonenvironment\Lib\site-packages\pandas\core\frame.py:10493, in DataFrame.map.<locals>.infer(x)
#   10492 def infer(x):
# > 10493     return x._map_values(func, na_action=na_action)
#
# File c:\Users\Ideapad\.conda\envs\Pythonenvironment\Lib\site-packages\pandas\core\base.py:925, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     922 if isinstance(arr, ExtensionArray):
#     923     return arr.map(mapper, na_action=na_action)
# --> 925 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\Ideapad\.conda\envs\Pythonenvironment\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File pandas/_libs/lib.pyx:2999, in pandas._libs.lib.map_infer()
#
# Cell In[70], line 8, in to_float(x)
#       6     return float(x)
#       7 else:
# ----> 8     return float(x[0:2])
#
# TypeError: 'float' object is not subscriptable

# %% [markdown]
# Now let's look at the data types of the columns:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18054 entries, Cristiano Ronaldo to K. Koulibaly
# Data columns (total 39 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       18054 non-null  int64
#  1   Nationality               18054 non-null  object
#  2   Overall                   18054 non-null  float64
#  3   Acceleration              18054 non-null  float64
#  4   Aggression                18054 non-null  float64
#  5   Agility                   18054 non-null  float64
#  6   Balance                   18054 non-null  float64
#  7   Ball control              18054 non-null  float64
#  8   Composure                 18054 non-null  float64
#  9   Crossing                  18054 non-null  float64
#  10  Curve                     18054 non-null  float64
#  11  Dribbling                 18054 non-null  float64
#  12  Finishing                 18054 non-null  float64
#  13  Free kick accuracy        18054 non-null  float64
#  14  GK diving                 18054 non-null  float64
#  15  GK handling               18054 non-null  float64
#  16  GK kicking                18054 non-null  float64
#  17  GK positioning            18054 non-null  float64
#  18  GK reflexes               18054 non-null  float64
#  19  Heading accuracy          18054 non-null  float64
#  20  Interceptions             18054 non-null  float64
#  21  Jumping                   18054 non-null  float64
#  22  Long passing              18054 non-null  float64
#  23  Long shots                18054 non-null  float64
#  24  Marking                   18054 non-null  float64
#  25  Penalties                 18054 non-null  float64
#  26  Positioning               18054 non-null  float64
#  27  Reactions                 18054 non-null  float64
#  28  Short passing             18054 non-null  float64
#  29  Shot power                18054 non-null  float64
#  30  Sliding tackle            18054 non-null  float64
#  31  Sprint speed              18054 non-null  float64
#  32  Stamina                   18054 non-null  float64
#  33  Standing tackle           18054 non-null  float64
#  34  Strength                  18054 non-null  float64
#  35  Vision                    18054 non-null  float64
#  36  Volleys                   18054 non-null  float64
#  37  Preferred Positions       18054 non-null  object
#  38  Preferred Positions Type  18054 non-null  object
# dtypes: float64(35), int64(1), object(3)
# memory usage: 6.0+ MB

# %% [markdown]
# We can see that the columns have been transformed to the `float` type successfully.
